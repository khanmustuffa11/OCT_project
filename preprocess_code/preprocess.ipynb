# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\mkhan\\Desktop\\musabi\\OCT_project\\data\\OCT_final_testwcsv.csv")
df
# Out:
#        Unnamed: 0                    image  level
# 0               0   image_normal_0_11.tiff      0  \
# 1               1   image_normal_0_13.tiff      0
# 2               2    image_normal_0_5.tiff      0
# 3               3  image_normal_10_14.tiff      0
# 4               4  image_normal_10_15.tiff      0
# ...           ...                      ...    ...
# 22313       22313      CNV-9997680-70.jpeg      3
# 22314       22314      CNV-9997680-76.jpeg      3
# 22315       22315      CNV-9997680-81.jpeg      3
# 22316       22316      CNV-9997680-84.jpeg      3
# 22317       22317      CNV-9997680-88.jpeg      3
#
#                                                     path       source
# 0      data/oct/oct_artelus/val/0/image_normal_0_11.tiff  oct_artelus
# 1      data/oct/oct_artelus/val/0/image_normal_0_13.tiff  oct_artelus
# 2       data/oct/oct_artelus/val/0/image_normal_0_5.tiff  oct_artelus
# 3      data/oct/oct_artelus/val/0/image_normal_10_14....  oct_artelus
# ...

# %%
df = pd.read_csv("OCT_final_testwcsv.csv")
df
# Out:
#                     image  level
# 0             AMRD24.tiff      4  \
# 1             AMRD33.tiff      4
# 2     image_amd_0_16.tiff      4
# 3     image_amd_0_19.tiff      4
# 4     image_amd_10_0.tiff      4
# ...                   ...    ...
# 1148   CNV-9782524-1.jpeg      3
# 1149   CNV-9782524-2.jpeg      3
# 1150   CNV-9806464-1.jpeg      3
# 1151   CNV-9929999-1.jpeg      3
# 1152   CNV-9971412-1.jpeg      3
#
#                                                  path       source
# 0             data/oct/oct_artelus/test/4/AMRD24.tiff  oct_artelus
# 1             data/oct/oct_artelus/test/4/AMRD33.tiff  oct_artelus
# 2     data/oct/oct_artelus/test/4/image_amd_0_16.tiff  oct_artelus
# 3     data/oct/oct_artelus/test/4/image_amd_0_19.tiff  oct_artelus
# 4     data/oct/oct_artelus/test/4/image_amd_10_0.tiff  oct_artelus
# ...                                               ...          ...
# 1148               data/oct/test/3/CNV-9782524-1.jpeg          NaN
# ...

# %%
df2 = pd.get_dummies(df, columns=['level'])
df2
# Out:
#                     image                                             path
# 0             AMRD24.tiff          data/oct/oct_artelus/test/4/AMRD24.tiff  \
# 1             AMRD33.tiff          data/oct/oct_artelus/test/4/AMRD33.tiff
# 2     image_amd_0_16.tiff  data/oct/oct_artelus/test/4/image_amd_0_16.tiff
# 3     image_amd_0_19.tiff  data/oct/oct_artelus/test/4/image_amd_0_19.tiff
# 4     image_amd_10_0.tiff  data/oct/oct_artelus/test/4/image_amd_10_0.tiff
# ...                   ...                                              ...
# 1148   CNV-9782524-1.jpeg               data/oct/test/3/CNV-9782524-1.jpeg
# 1149   CNV-9782524-2.jpeg               data/oct/test/3/CNV-9782524-2.jpeg
# 1150   CNV-9806464-1.jpeg               data/oct/test/3/CNV-9806464-1.jpeg
# 1151   CNV-9929999-1.jpeg               data/oct/test/3/CNV-9929999-1.jpeg
# 1152   CNV-9971412-1.jpeg               data/oct/test/3/CNV-9971412-1.jpeg
#
# ...

# %%
df2.to_csv("oct_final_test_vit.csv")
